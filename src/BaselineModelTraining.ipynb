# %%
import tensorflow as tf
from keras.layers import Embedding, GRU, Dense, Dropout, Input, Concatenate
from keras.models import Model
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy

MAX_SEQUENCE_LENGTH = 16750

def buildModel():
    # Define model hyperparameters
    VOCAB_SIZE = 82
    OUTPUT_DIM = 5
    HIDDEN_UNITS_GRU = 64
    HIDDEN_UNITS_DENSE = [128, 64, 1]
    DROPOUT_RATE = 0.2
    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    NUM_LABELS = 5 # excluding label 4: 0, 1, 2, 3, 5
    NUM_BRANCHES = NUM_LABELS  # Excluding label 4

    # Define the stem layer (feature extractor)
    inputs = Input(shape=(MAX_SEQUENCE_LENGTH,))
    embedding = Embedding(input_dim=VOCAB_SIZE, output_dim=OUTPUT_DIM, input_length=MAX_SEQUENCE_LENGTH)(inputs)
    gru_output = GRU(HIDDEN_UNITS_GRU)(embedding)

    # Define the vulnerability branches
    branches = []
    for i in range(NUM_BRANCHES):
        dense1 = Dense(HIDDEN_UNITS_DENSE[0])(gru_output)
        dropout = Dropout(DROPOUT_RATE)(dense1)
        dense2 = Dense(HIDDEN_UNITS_DENSE[1])(dropout)
        dense3 = Dense(HIDDEN_UNITS_DENSE[2], activation='sigmoid', name=f'output_{i}')(dense2)
        branches.append(dense3)

    # # Concatenate the branches and create the model
    # concatenated = Concatenate()(branches)
    model = Model(inputs=inputs, outputs=branches)

    label_metrics = {}
    for i in range(NUM_BRANCHES):
        label_metrics[f'output_{i}'] = 'accuracy'

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
                  loss=BinaryCrossentropy(from_logits=False),
                  metrics=label_metrics)

    return model

model = buildModel()
num_outputs = len(model.outputs)
print("Number of outputs:", num_outputs)
print('model output names:')
print(model.output_names)
# Print the model summary
# model.summary()
# Out:
# Number of outputs: 5
# model output names:
# ['output_0', 'output_1', 'output_2', 'output_3', 'output_4']

# %%
from keras.callbacks import Callback

class MetricsCallback(Callback):
    def __init__(self):
        super(MetricsCallback, self).__init__()
        self.chunk_metrics = []

    def on_epoch_end(self, epoch, logs=None):
        chunk_loss = []
        chunk_accuracy = []

        # Compute loss and accuracy for each output
        for output_name in self.model.output_names:
            loss_key = f'{output_name}_loss'
            accuracy_key = f'{output_name}_accuracy'

            if loss_key in logs:
                chunk_loss.append(logs[loss_key])
            if accuracy_key in logs:
                chunk_accuracy.append(logs[accuracy_key])

        self.chunk_metrics.append({'loss': chunk_loss, 'accuracy': chunk_accuracy})

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
# traing with hdf5 datasets

import tensorflow as tf
import pandas as pd
import h5py
from google.colab import drive
from sklearn.metrics import precision_recall_fscore_support
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define datasets
# Open the HDF5 file
hdf5_file_training = h5py.File('/content/drive/MyDrive/Practicum/HDF5Data/training.h5', 'r')
hdf5_file_validation = h5py.File('/content/drive/MyDrive/Practicum/HDF5Data/validation.h5', 'r')

# Get the dataset you want to iterate over
training_data = hdf5_file_training['data']
training_labels = hdf5_file_training['labels']
print(f'training data shape: {training_data.shape}')
print(f'training labels shape: {training_labels.shape}')

validation_data = hdf5_file_validation['data']
validation_labels = hdf5_file_validation['labels']
print(f'validation data shape: {validation_data.shape}')
print(f'validation labels shape: {validation_labels.shape}')


# Define the total number of chunks for each dataset
num_train_chunks = 70
# num_val_chunks = 11
# num_test_chunks = 16

# Define other model hyperparameters
num_epochs = 1
batch_size = 32

labelsColumns = [0, 1, 2, 3, 5]

# Load the model
model = buildModel()  # Replace with the actual path to your model file

print('model output names:')
print(model.output_names)

# Get the total number of rows in the dataset
total_rows_training = training_data.shape[0]

# Set the chunk size
chunk_size = 1024

# Training phase
for epoch in range(num_epochs):
    trainingCtr = 0
    metrics_callback_2 = MetricsCallback()

    for i in range(0, total_rows_training, chunk_size):

        # Calculate the start and end indices for the current chunk
        start_index = i
        end_index = min(i + chunk_size, total_rows_training)

        # Get the chunk of data & labels
        train_X = training_data[start_index:end_index][:, 0:MAX_SEQUENCE_LENGTH]
        labels = training_labels[start_index:end_index]
        label_0 = labels[:, 0]
        label_1 = labels[:, 1]
        label_2 = labels[:, 2]
        label_3 = labels[:, 3]
        label_4 = labels[:, 5]

        # Train the model on the chunked data
        model.fit(train_X, {'output_0': label_0, 'output_1': label_1, 'output_2': label_2, 'output_3': label_3, 'output_4': label_4}, callbacks=[metrics_callback_2], batch_size=batch_size, epochs=1, verbose=1)

        trainingCtr += 1
        print(f'trained chunk: {trainingCtr}')

        # # After each chunk, evaluate the model on the validation data
        # val_X = validation_data[:][:, 0:MAX_SEQUENCE_LENGTH]
        # val_labels = validation_labels[:]
        # val_label_0 = val_labels[:, 0]
        # val_label_1 = val_labels[:, 1]
        # val_label_2 = val_labels[:, 2]
        # val_label_3 = val_labels[:, 3]
        # val_label_4 = val_labels[:, 5]
        # evaluation_results = model.evaluate(val_X, {'output_0': val_label_4, 'output_1': val_label_3, 'output_2': val_label_2, 'output_3': val_label_1, 'output_4': val_label_0}, verbose=0)
        # # Print the loss and accuracy for each label
        # for result in evaluation_results:
        #     print(result, end=' ')

    # last validation set evaluation
    val_X = validation_data[:][:, 0:MAX_SEQUENCE_LENGTH]
    val_labels = validation_labels[:]
    val_label_0 = val_labels[:, 0]
    val_label_1 = val_labels[:, 1]
    val_label_2 = val_labels[:, 2]
    val_label_3 = val_labels[:, 3]
    val_label_4 = val_labels[:, 5]
    evaluation_results = model.evaluate(val_X, {'output_0': val_label_0, 'output_1': val_label_1, 'output_2': val_label_2, 'output_3': val_label_3, 'output_4': val_label_4}, verbose=0)
    # Print the loss and accuracy for each label
    for result in evaluation_results:
        print(result, end=' ')

    # Calculate precision, recall and
    val_labels_list = [val_labels[:, i].tolist() for i in range(val_labels.shape[1])]
    _ = val_labels_list.pop(4) # remove labels for clean contracts

    predictions = model.predict(val_X)
    predictions_array = np.array(predictions)

    # Convert the predictions to binary format (e.g., using a threshold of 0.5)
    binary_predictions = (predictions_array >= 0.5).astype(int)

    # Calculate precision, recall, and F1-score for each label
    precision, recall, f1_score, _ = precision_recall_fscore_support(val_labels_list[0], binary_predictions[0], average=None)

    for i in range(0, 5):
        # Calculate precision, recall, and F1-score for each label
        precision, recall, f1_score, _ = precision_recall_fscore_support(val_labels_list[i], binary_predictions[i], average=None)
        print(f"Label {i}: Precision={precision}, Recall={recall}, F1-score={f1_score}")


# Save the trained model
model.save("/content/drive/MyDrive/Practicum/TrainedModel/model_escort_design_1.h5")

# # Testing phase
# test_loss = 0.0
# test_accuracy = 0.0
# num_test_samples = 0

# for test_chunk_idx in range(num_test_chunks):
#     # Load the chunked test data
#     test_df = pd.read_csv(test_data_path.format(test_chunk_idx))
#     test_X = test_df.iloc[:, 0:24600].values  # Input sequences
#     test_y = test_df.iloc[:, 24600:].values   # Labels

#     # Evaluate the model on the test data
#     loss, accuracy = model.evaluate(test_X, test_y, verbose=0)
#     test_loss += loss * len(test_X)
#     test_accuracy += accuracy * len(test_X)
#     num_test_samples += len(test_X)

# # Compute the average test loss and accuracy
# test_loss /= num_test_samples
# test_accuracy /= num_test_samples
# print(f'Test loss: {test_loss:.4f}, accuracy: {test_accuracy:.4f}')

# Close the HDF5 file
hdf5_file_training.close()
hdf5_file_validation.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# training data shape: (79414, 24600)
# training labels shape: (79414, 6)
# validation data shape: (10831, 24600)
# validation labels shape: (10831, 6)
# model output names:
# ['output_0', 'output_1', 'output_2', 'output_3', 'output_4']
# 32/32 [==============================] - 24s 504ms/step - loss: 2.9119 - output_0_loss: 0.4740 - output_1_loss: 0.5545 - output_2_loss: 0.6049 - output_3_loss: 0.6161 - output_4_loss: 0.6625 - output_0_accuracy: 0.8418 - output_1_accuracy: 0.7852 - output_2_accuracy: 0.7168 - output_3_accuracy: 0.7002 - output_4_accuracy: 0.6289
# trained chunk: 1
# 32/32 [==============================] - 15s 470ms/step - loss: 2.7846 - output_0_loss: 0.4526 - output_1_loss: 0.4649 - output_2_loss: 0.5821 - output_3_loss: 0.6032 - output_4_loss: 0.6818 - output_0_accuracy: 0.8281 - output_1_accuracy: 0.8262 - output_2_accuracy: 0.7275 - output_3_accuracy: 0.7002 - output_4_accuracy: 0.5742
# trained chunk: 2
# 32/32 [==============================] - 15s 473ms/step - loss: 2.7130 - output_0_loss: 0.4165 - output_1_loss: 0.4699 - output_2_loss: 0.5539 - output_3_loss: 0.6047 - output_4_loss: 0.6679 - output_0_accuracy: 0.8535 - output_1_accuracy: 0.8203 - output_2_accuracy: 0.7480 - output_3_accuracy: 0.6973 - output_4_accuracy: 0.6211
# trained chunk: 3
# 32/32 [==============================] - 16s 468ms/step - loss: 2.7443 - output_0_loss: 0.4423 - output_1_loss: 0.4471 - output_2_loss: 0.5555 - output_3_loss: 0.6280 - output_4_loss: 0.6714 - output_0_accuracy: 0.8369 - output_1_accuracy: 0.8340 - output_2_accuracy: 0.7549 - output_3_accuracy: 0.6670 - output_4_accuracy: 0.6230
# trained chunk: 4
# 32/32 [==============================] - 15s 469ms/step - loss: 2.8106 - output_0_loss: 0.4460 - output_1_loss: 0.4752 - output_2_loss: 0.5821 - output_3_loss: 0.6354 - output_4_loss: 0.6719 - output_0_accuracy: 0.8330 - output_1_accuracy: 0.8125 - output_2_accuracy: 0.7314 - output_3_accuracy: 0.6572 - output_4_accuracy: 0.5811
# trained chunk: 5
# 32/32 [==============================] - 16s 482ms/step - loss: 2.6587 - output_0_loss: 0.4246 - output_1_loss: 0.4283 - output_2_loss: 0.5482 - output_3_loss: 0.6016 - output_4_loss: 0.6560 - output_0_accuracy: 0.8477 - output_1_accuracy: 0.8438 - output_2_accuracy: 0.7598 - output_3_accuracy: 0.7109 - output_4_accuracy: 0.6309
# trained chunk: 6
# 32/32 [==============================] - 15s 468ms/step - loss: 2.6856 - output_0_loss: 0.4319 - output_1_loss: 0.4368 - output_2_loss: 0.5486 - output_3_loss: 0.6136 - output_4_loss: 0.6548 - output_0_accuracy: 0.8438 - output_1_accuracy: 0.8330 - output_2_accuracy: 0.7529 - output_3_accuracy: 0.6904 - output_4_accuracy: 0.6299
# trained chunk: 7
# 32/32 [==============================] - 16s 485ms/step - loss: 2.7114 - output_0_loss: 0.4463 - output_1_loss: 0.4470 - output_2_loss: 0.5446 - output_3_loss: 0.6109 - output_4_loss: 0.6626 - output_0_accuracy: 0.8320 - output_1_accuracy: 0.8301 - output_2_accuracy: 0.7559 - output_3_accuracy: 0.6934 - output_4_accuracy: 0.6211
# trained chunk: 8
# 32/32 [==============================] - 16s 470ms/step - loss: 2.7528 - output_0_loss: 0.4367 - output_1_loss: 0.4601 - output_2_loss: 0.5700 - output_3_loss: 0.6233 - output_4_loss: 0.6627 - output_0_accuracy: 0.8438 - output_1_accuracy: 0.8281 - output_2_accuracy: 0.7334 - output_3_accuracy: 0.6768 - output_4_accuracy: 0.6191
# trained chunk: 9
# 32/32 [==============================] - 15s 472ms/step - loss: 2.7052 - output_0_loss: 0.4289 - output_1_loss: 0.4444 - output_2_loss: 0.5604 - output_3_loss: 0.6168 - output_4_loss: 0.6547 - output_0_accuracy: 0.8457 - output_1_accuracy: 0.8359 - output_2_accuracy: 0.7383 - output_3_accuracy: 0.6855 - output_4_accuracy: 0.6279
# trained chunk: 10
# 32/32 [==============================] - 16s 472ms/step - loss: 2.7909 - output_0_loss: 0.4621 - output_1_loss: 0.4735 - output_2_loss: 0.5770 - output_3_loss: 0.6166 - output_4_loss: 0.6617 - output_0_accuracy: 0.8252 - output_1_accuracy: 0.8164 - output_2_accuracy: 0.7246 - output_3_accuracy: 0.6875 - output_4_accuracy: 0.6182
# trained chunk: 11
# 32/32 [==============================] - 15s 466ms/step - loss: 2.7599 - output_0_loss: 0.4386 - output_1_loss: 0.4650 - output_2_loss: 0.5497 - output_3_loss: 0.6481 - output_4_loss: 0.6585 - output_0_accuracy: 0.8408 - output_1_accuracy: 0.8213 - output_2_accuracy: 0.7578 - output_3_accuracy: 0.6523 - output_4_accuracy: 0.6211
# trained chunk: 12
# 32/32 [==============================] - 16s 483ms/step - loss: 2.7589 - output_0_loss: 0.4388 - output_1_loss: 0.4725 - output_2_loss: 0.5648 - output_3_loss: 0.6225 - output_4_loss: 0.6604 - output_0_accuracy: 0.8369 - output_1_accuracy: 0.8223 - output_2_accuracy: 0.7480 - output_3_accuracy: 0.6787 - output_4_accuracy: 0.6240
# trained chunk: 13
# 32/32 [==============================] - 15s 480ms/step - loss: 2.7209 - output_0_loss: 0.4169 - output_1_loss: 0.4673 - output_2_loss: 0.5596 - output_3_loss: 0.6205 - output_4_loss: 0.6567 - output_0_accuracy: 0.8516 - output_1_accuracy: 0.8242 - output_2_accuracy: 0.7520 - output_3_accuracy: 0.6807 - output_4_accuracy: 0.6309
# trained chunk: 14
# 32/32 [==============================] - 15s 466ms/step - loss: 2.6554 - output_0_loss: 0.4238 - output_1_loss: 0.4504 - output_2_loss: 0.5526 - output_3_loss: 0.5895 - output_4_loss: 0.6390 - output_0_accuracy: 0.8486 - output_1_accuracy: 0.8340 - output_2_accuracy: 0.7549 - output_3_accuracy: 0.7119 - output_4_accuracy: 0.6475
# trained chunk: 15
# 32/32 [==============================] - 15s 469ms/step - loss: 2.7804 - output_0_loss: 0.4563 - output_1_loss: 0.4734 - output_2_loss: 0.5636 - output_3_loss: 0.6201 - output_4_loss: 0.6671 - output_0_accuracy: 0.8301 - output_1_accuracy: 0.8174 - output_2_accuracy: 0.7402 - output_3_accuracy: 0.6875 - output_4_accuracy: 0.6084
# trained chunk: 16
# 32/32 [==============================] - 15s 474ms/step - loss: 2.7280 - output_0_loss: 0.4396 - output_1_loss: 0.4529 - output_2_loss: 0.5780 - output_3_loss: 0.6118 - output_4_loss: 0.6457 - output_0_accuracy: 0.8369 - output_1_accuracy: 0.8291 - output_2_accuracy: 0.7324 - output_3_accuracy: 0.6875 - output_4_accuracy: 0.6484
# trained chunk: 17
# 32/32 [==============================] - 15s 470ms/step - loss: 2.8205 - output_0_loss: 0.4567 - output_1_loss: 0.4807 - output_2_loss: 0.5910 - output_3_loss: 0.6284 - output_4_loss: 0.6636 - output_0_accuracy: 0.8301 - output_1_accuracy: 0.8115 - output_2_accuracy: 0.7178 - output_3_accuracy: 0.6738 - output_4_accuracy: 0.6172
# trained chunk: 18
# 32/32 [==============================] - 15s 477ms/step - loss: 2.7675 - output_0_loss: 0.4549 - output_1_loss: 0.4615 - output_2_loss: 0.5611 - output_3_loss: 0.6259 - output_4_loss: 0.6640 - output_0_accuracy: 0.8320 - output_1_accuracy: 0.8291 - output_2_accuracy: 0.7471 - output_3_accuracy: 0.6826 - output_4_accuracy: 0.6152
# trained chunk: 19
# 32/32 [==============================] - 15s 473ms/step - loss: 2.7901 - output_0_loss: 0.4473 - output_1_loss: 0.5031 - output_2_loss: 0.5503 - output_3_loss: 0.6215 - output_4_loss: 0.6680 - output_0_accuracy: 0.8340 - output_1_accuracy: 0.7979 - output_2_accuracy: 0.7529 - output_3_accuracy: 0.6836 - output_4_accuracy: 0.6162
# trained chunk: 20
# 32/32 [==============================] - 15s 475ms/step - loss: 2.7040 - output_0_loss: 0.4750 - output_1_loss: 0.4257 - output_2_loss: 0.5479 - output_3_loss: 0.6033 - output_4_loss: 0.6521 - output_0_accuracy: 0.8223 - output_1_accuracy: 0.8506 - output_2_accuracy: 0.7607 - output_3_accuracy: 0.7021 - output_4_accuracy: 0.6387
# trained chunk: 21
# 32/32 [==============================] - 15s 469ms/step - loss: 2.7514 - output_0_loss: 0.4483 - output_1_loss: 0.4746 - output_2_loss: 0.5442 - output_3_loss: 0.6245 - output_4_loss: 0.6598 - output_0_accuracy: 0.8330 - output_1_accuracy: 0.8193 - output_2_accuracy: 0.7627 - output_3_accuracy: 0.6797 - output_4_accuracy: 0.6172
# trained chunk: 22
# 32/32 [==============================] - 15s 475ms/step - loss: 2.7228 - output_0_loss: 0.4254 - output_1_loss: 0.4739 - output_2_loss: 0.5464 - output_3_loss: 0.6299 - output_4_loss: 0.6472 - output_0_accuracy: 0.8496 - output_1_accuracy: 0.8203 - output_2_accuracy: 0.7617 - output_3_accuracy: 0.6719 - output_4_accuracy: 0.6406
# trained chunk: 23
# 32/32 [==============================] - 15s 468ms/step - loss: 2.7049 - output_0_loss: 0.4690 - output_1_loss: 0.4479 - output_2_loss: 0.5335 - output_3_loss: 0.6105 - output_4_loss: 0.6440 - output_0_accuracy: 0.8232 - output_1_accuracy: 0.8350 - output_2_accuracy: 0.7686 - output_3_accuracy: 0.6924 - output_4_accuracy: 0.6572
# trained chunk: 24
# 32/32 [==============================] - 16s 471ms/step - loss: 2.7290 - output_0_loss: 0.4239 - output_1_loss: 0.4770 - output_2_loss: 0.5638 - output_3_loss: 0.6064 - output_4_loss: 0.6579 - output_0_accuracy: 0.8438 - output_1_accuracy: 0.8135 - output_2_accuracy: 0.7402 - output_3_accuracy: 0.7041 - output_4_accuracy: 0.6328
# trained chunk: 25
# 32/32 [==============================] - 15s 472ms/step - loss: 2.6780 - output_0_loss: 0.4195 - output_1_loss: 0.4737 - output_2_loss: 0.5538 - output_3_loss: 0.5913 - output_4_loss: 0.6397 - output_0_accuracy: 0.8496 - output_1_accuracy: 0.8193 - output_2_accuracy: 0.7490 - output_3_accuracy: 0.7139 - output_4_accuracy: 0.6621
# trained chunk: 26
# 32/32 [==============================] - 16s 465ms/step - loss: 2.7050 - output_0_loss: 0.4344 - output_1_loss: 0.4467 - output_2_loss: 0.5537 - output_3_loss: 0.6081 - output_4_loss: 0.6621 - output_0_accuracy: 0.8438 - output_1_accuracy: 0.8359 - output_2_accuracy: 0.7549 - output_3_accuracy: 0.7070 - output_4_accuracy: 0.6191
# trained chunk: 27
# 32/32 [==============================] - 15s 475ms/step - loss: 2.6776 - output_0_loss: 0.4408 - output_1_loss: 0.4557 - output_2_loss: 0.5270 - output_3_loss: 0.6032 - output_4_loss: 0.6510 - output_0_accuracy: 0.8408 - output_1_accuracy: 0.8301 - output_2_accuracy: 0.7705 - output_3_accuracy: 0.7041 - output_4_accuracy: 0.6387
# trained chunk: 28
# 32/32 [==============================] - 18s 506ms/step - loss: 2.6384 - output_0_loss: 0.4114 - output_1_loss: 0.4284 - output_2_loss: 0.5155 - output_3_loss: 0.6194 - output_4_loss: 0.6637 - output_0_accuracy: 0.8535 - output_1_accuracy: 0.8457 - output_2_accuracy: 0.7793 - output_3_accuracy: 0.6846 - output_4_accuracy: 0.6055
# trained chunk: 29
# 32/32 [==============================] - 15s 467ms/step - loss: 2.7338 - output_0_loss: 0.4306 - output_1_loss: 0.4794 - output_2_loss: 0.5608 - output_3_loss: 0.6137 - output_4_loss: 0.6493 - output_0_accuracy: 0.8438 - output_1_accuracy: 0.8135 - output_2_accuracy: 0.7480 - output_3_accuracy: 0.6963 - output_4_accuracy: 0.6318
# trained chunk: 30
# 32/32 [==============================] - 15s 476ms/step - loss: 2.6898 - output_0_loss: 0.4040 - output_1_loss: 0.4518 - output_2_loss: 0.5758 - output_3_loss: 0.5981 - output_4_loss: 0.6601 - output_0_accuracy: 0.8604 - output_1_accuracy: 0.8301 - output_2_accuracy: 0.7256 - output_3_accuracy: 0.7129 - output_4_accuracy: 0.5938
# trained chunk: 31
# 32/32 [==============================] - 15s 475ms/step - loss: 2.6974 - output_0_loss: 0.3961 - output_1_loss: 0.4690 - output_2_loss: 0.5775 - output_3_loss: 0.5830 - output_4_loss: 0.6718 - output_0_accuracy: 0.8613 - output_1_accuracy: 0.8154 - output_2_accuracy: 0.7295 - output_3_accuracy: 0.7275 - output_4_accuracy: 0.5781
# trained chunk: 32
# 32/32 [==============================] - 15s 472ms/step - loss: 2.5805 - output_0_loss: 0.3651 - output_1_loss: 0.4170 - output_2_loss: 0.5525 - output_3_loss: 0.5760 - output_4_loss: 0.6700 - output_0_accuracy: 0.8770 - output_1_accuracy: 0.8535 - output_2_accuracy: 0.7529 - output_3_accuracy: 0.7236 - output_4_accuracy: 0.5908
# trained chunk: 33
# 32/32 [==============================] - 15s 466ms/step - loss: 2.6921 - output_0_loss: 0.3997 - output_1_loss: 0.4606 - output_2_loss: 0.5749 - output_3_loss: 0.5866 - output_4_loss: 0.6704 - output_0_accuracy: 0.8633 - output_1_accuracy: 0.8242 - output_2_accuracy: 0.7314 - output_3_accuracy: 0.7188 - output_4_accuracy: 0.5889
# trained chunk: 34
# 32/32 [==============================] - 15s 475ms/step - loss: 2.6252 - output_0_loss: 0.3987 - output_1_loss: 0.4151 - output_2_loss: 0.5519 - output_3_loss: 0.5871 - output_4_loss: 0.6724 - output_0_accuracy: 0.8633 - output_1_accuracy: 0.8496 - output_2_accuracy: 0.7539 - output_3_accuracy: 0.7227 - output_4_accuracy: 0.5557
# trained chunk: 35
# 32/32 [==============================] - 15s 475ms/step - loss: 2.6717 - output_0_loss: 0.4152 - output_1_loss: 0.4489 - output_2_loss: 0.5434 - output_3_loss: 0.5959 - output_4_loss: 0.6682 - output_0_accuracy: 0.8535 - output_1_accuracy: 0.8271 - output_2_accuracy: 0.7656 - output_3_accuracy: 0.7080 - output_4_accuracy: 0.5674
# trained chunk: 36
# 32/32 [==============================] - 15s 469ms/step - loss: 2.6571 - output_0_loss: 0.4067 - output_1_loss: 0.4317 - output_2_loss: 0.5643 - output_3_loss: 0.5863 - output_4_loss: 0.6681 - output_0_accuracy: 0.8535 - output_1_accuracy: 0.8418 - output_2_accuracy: 0.7480 - output_3_accuracy: 0.7236 - output_4_accuracy: 0.5957
# trained chunk: 37
# 32/32 [==============================] - 15s 469ms/step - loss: 2.6683 - output_0_loss: 0.4143 - output_1_loss: 0.4605 - output_2_loss: 0.5386 - output_3_loss: 0.5942 - output_4_loss: 0.6607 - output_0_accuracy: 0.8564 - output_1_accuracy: 0.8262 - output_2_accuracy: 0.7666 - output_3_accuracy: 0.7119 - output_4_accuracy: 0.5977
# trained chunk: 38
# 32/32 [==============================] - 15s 470ms/step - loss: 2.6601 - output_0_loss: 0.3652 - output_1_loss: 0.4541 - output_2_loss: 0.5536 - output_3_loss: 0.6002 - output_4_loss: 0.6871 - output_0_accuracy: 0.8818 - output_1_accuracy: 0.8262 - output_2_accuracy: 0.7549 - output_3_accuracy: 0.6982 - output_4_accuracy: 0.5596
# trained chunk: 39
# 32/32 [==============================] - 15s 474ms/step - loss: 2.6987 - output_0_loss: 0.4037 - output_1_loss: 0.4506 - output_2_loss: 0.5572 - output_3_loss: 0.6124 - output_4_loss: 0.6748 - output_0_accuracy: 0.8584 - output_1_accuracy: 0.8311 - output_2_accuracy: 0.7441 - output_3_accuracy: 0.6875 - output_4_accuracy: 0.5723
# trained chunk: 40
# 32/32 [==============================] - 15s 468ms/step - loss: 2.6503 - output_0_loss: 0.4005 - output_1_loss: 0.4385 - output_2_loss: 0.5329 - output_3_loss: 0.6025 - output_4_loss: 0.6758 - output_0_accuracy: 0.8623 - output_1_accuracy: 0.8369 - output_2_accuracy: 0.7725 - output_3_accuracy: 0.7041 - output_4_accuracy: 0.5576
# trained chunk: 41
# 32/32 [==============================] - 15s 466ms/step - loss: 2.6838 - output_0_loss: 0.4001 - output_1_loss: 0.4238 - output_2_loss: 0.5570 - output_3_loss: 0.6182 - output_4_loss: 0.6846 - output_0_accuracy: 0.8623 - output_1_accuracy: 0.8438 - output_2_accuracy: 0.7490 - output_3_accuracy: 0.6826 - output_4_accuracy: 0.5332
# trained chunk: 42
# 32/32 [==============================] - 15s 473ms/step - loss: 2.6056 - output_0_loss: 0.3765 - output_1_loss: 0.4318 - output_2_loss: 0.5277 - output_3_loss: 0.5947 - output_4_loss: 0.6749 - output_0_accuracy: 0.8750 - output_1_accuracy: 0.8340 - output_2_accuracy: 0.7754 - output_3_accuracy: 0.7158 - output_4_accuracy: 0.5811
# trained chunk: 43
# 32/32 [==============================] - 15s 471ms/step - loss: 2.6865 - output_0_loss: 0.3891 - output_1_loss: 0.4603 - output_2_loss: 0.5671 - output_3_loss: 0.5973 - output_4_loss: 0.6727 - output_0_accuracy: 0.8672 - output_1_accuracy: 0.8281 - output_2_accuracy: 0.7422 - output_3_accuracy: 0.7109 - output_4_accuracy: 0.5742
# trained chunk: 44
# 32/32 [==============================] - 15s 474ms/step - loss: 2.6193 - output_0_loss: 0.4118 - output_1_loss: 0.4254 - output_2_loss: 0.5506 - output_3_loss: 0.5615 - output_4_loss: 0.6700 - output_0_accuracy: 0.8564 - output_1_accuracy: 0.8447 - output_2_accuracy: 0.7510 - output_3_accuracy: 0.7441 - output_4_accuracy: 0.5869
# trained chunk: 45
# 32/32 [==============================] - 16s 480ms/step - loss: 2.6579 - output_0_loss: 0.3932 - output_1_loss: 0.4532 - output_2_loss: 0.5294 - output_3_loss: 0.6002 - output_4_loss: 0.6819 - output_0_accuracy: 0.8643 - output_1_accuracy: 0.8281 - output_2_accuracy: 0.7744 - output_3_accuracy: 0.7061 - output_4_accuracy: 0.5654
# trained chunk: 46
# 32/32 [==============================] - 15s 471ms/step - loss: 2.5827 - output_0_loss: 0.3734 - output_1_loss: 0.4240 - output_2_loss: 0.5329 - output_3_loss: 0.5831 - output_4_loss: 0.6694 - output_0_accuracy: 0.8779 - output_1_accuracy: 0.8438 - output_2_accuracy: 0.7598 - output_3_accuracy: 0.7295 - output_4_accuracy: 0.5938
# trained chunk: 47
# 32/32 [==============================] - 15s 482ms/step - loss: 2.6617 - output_0_loss: 0.4020 - output_1_loss: 0.4257 - output_2_loss: 0.5732 - output_3_loss: 0.5880 - output_4_loss: 0.6728 - output_0_accuracy: 0.8613 - output_1_accuracy: 0.8486 - output_2_accuracy: 0.7256 - output_3_accuracy: 0.7148 - output_4_accuracy: 0.5830
# trained chunk: 48
# 32/32 [==============================] - 15s 470ms/step - loss: 2.6364 - output_0_loss: 0.3719 - output_1_loss: 0.4500 - output_2_loss: 0.5593 - output_3_loss: 0.5820 - output_4_loss: 0.6732 - output_0_accuracy: 0.8740 - output_1_accuracy: 0.8311 - output_2_accuracy: 0.7461 - output_3_accuracy: 0.7344 - output_4_accuracy: 0.5723
# trained chunk: 49
# 32/32 [==============================] - 15s 471ms/step - loss: 2.6451 - output_0_loss: 0.3891 - output_1_loss: 0.4255 - output_2_loss: 0.5599 - output_3_loss: 0.6118 - output_4_loss: 0.6588 - output_0_accuracy: 0.8662 - output_1_accuracy: 0.8369 - output_2_accuracy: 0.7324 - output_3_accuracy: 0.6953 - output_4_accuracy: 0.6113
# trained chunk: 50
# 32/32 [==============================] - 15s 465ms/step - loss: 2.6193 - output_0_loss: 0.3681 - output_1_loss: 0.4378 - output_2_loss: 0.5409 - output_3_loss: 0.5948 - output_4_loss: 0.6779 - output_0_accuracy: 0.8750 - output_1_accuracy: 0.8369 - output_2_accuracy: 0.7578 - output_3_accuracy: 0.7119 - output_4_accuracy: 0.5664
# trained chunk: 51
# 32/32 [==============================] - 15s 479ms/step - loss: 2.6469 - output_0_loss: 0.3983 - output_1_loss: 0.4175 - output_2_loss: 0.5670 - output_3_loss: 0.6011 - output_4_loss: 0.6631 - output_0_accuracy: 0.8594 - output_1_accuracy: 0.8486 - output_2_accuracy: 0.7412 - output_3_accuracy: 0.7100 - output_4_accuracy: 0.5928
# trained chunk: 52
# 32/32 [==============================] - 15s 467ms/step - loss: 2.6393 - output_0_loss: 0.3949 - output_1_loss: 0.4213 - output_2_loss: 0.5533 - output_3_loss: 0.5959 - output_4_loss: 0.6738 - output_0_accuracy: 0.8594 - output_1_accuracy: 0.8457 - output_2_accuracy: 0.7578 - output_3_accuracy: 0.7070 - output_4_accuracy: 0.5781
# trained chunk: 53
# 32/32 [==============================] - 15s 468ms/step - loss: 2.6772 - output_0_loss: 0.3857 - output_1_loss: 0.4594 - output_2_loss: 0.5539 - output_3_loss: 0.6063 - output_4_loss: 0.6719 - output_0_accuracy: 0.8662 - output_1_accuracy: 0.8242 - output_2_accuracy: 0.7490 - output_3_accuracy: 0.7051 - output_4_accuracy: 0.5293
# trained chunk: 54
# 32/32 [==============================] - 15s 466ms/step - loss: 2.6841 - output_0_loss: 0.4064 - output_1_loss: 0.4452 - output_2_loss: 0.5463 - output_3_loss: 0.6022 - output_4_loss: 0.6841 - output_0_accuracy: 0.8574 - output_1_accuracy: 0.8340 - output_2_accuracy: 0.7539 - output_3_accuracy: 0.7139 - output_4_accuracy: 0.5381
# trained chunk: 55
# 32/32 [==============================] - 15s 476ms/step - loss: 2.6537 - output_0_loss: 0.4216 - output_1_loss: 0.4121 - output_2_loss: 0.5526 - output_3_loss: 0.5854 - output_4_loss: 0.6820 - output_0_accuracy: 0.8467 - output_1_accuracy: 0.8525 - output_2_accuracy: 0.7520 - output_3_accuracy: 0.7207 - output_4_accuracy: 0.5039
# trained chunk: 56
# 32/32 [==============================] - 15s 469ms/step - loss: 2.6673 - output_0_loss: 0.3778 - output_1_loss: 0.4411 - output_2_loss: 0.5710 - output_3_loss: 0.5953 - output_4_loss: 0.6822 - output_0_accuracy: 0.8711 - output_1_accuracy: 0.8320 - output_2_accuracy: 0.7393 - output_3_accuracy: 0.7158 - output_4_accuracy: 0.5391
# trained chunk: 57
# 32/32 [==============================] - 15s 471ms/step - loss: 2.7084 - output_0_loss: 0.4161 - output_1_loss: 0.4440 - output_2_loss: 0.5731 - output_3_loss: 0.5954 - output_4_loss: 0.6798 - output_0_accuracy: 0.8574 - output_1_accuracy: 0.8281 - output_2_accuracy: 0.7334 - output_3_accuracy: 0.7119 - output_4_accuracy: 0.5615
# trained chunk: 58
# 32/32 [==============================] - 15s 467ms/step - loss: 2.6601 - output_0_loss: 0.3992 - output_1_loss: 0.4520 - output_2_loss: 0.5557 - output_3_loss: 0.5920 - output_4_loss: 0.6612 - output_0_accuracy: 0.8613 - output_1_accuracy: 0.8262 - output_2_accuracy: 0.7578 - output_3_accuracy: 0.7178 - output_4_accuracy: 0.5850
# trained chunk: 59
# 32/32 [==============================] - 15s 474ms/step - loss: 2.6409 - output_0_loss: 0.3634 - output_1_loss: 0.4440 - output_2_loss: 0.5479 - output_3_loss: 0.6047 - output_4_loss: 0.6810 - output_0_accuracy: 0.8818 - output_1_accuracy: 0.8379 - output_2_accuracy: 0.7568 - output_3_accuracy: 0.7061 - output_4_accuracy: 0.5547
# trained chunk: 60
# 32/32 [==============================] - 15s 468ms/step - loss: 2.6715 - output_0_loss: 0.3732 - output_1_loss: 0.4498 - output_2_loss: 0.5684 - output_3_loss: 0.6119 - output_4_loss: 0.6682 - output_0_accuracy: 0.8760 - output_1_accuracy: 0.8301 - output_2_accuracy: 0.7305 - output_3_accuracy: 0.6973 - output_4_accuracy: 0.5732
# trained chunk: 61
# 32/32 [==============================] - 15s 469ms/step - loss: 2.6865 - output_0_loss: 0.4117 - output_1_loss: 0.4390 - output_2_loss: 0.5628 - output_3_loss: 0.5966 - output_4_loss: 0.6763 - output_0_accuracy: 0.8535 - output_1_accuracy: 0.8359 - output_2_accuracy: 0.7471 - output_3_accuracy: 0.7109 - output_4_accuracy: 0.5723
# trained chunk: 62
# 32/32 [==============================] - 15s 472ms/step - loss: 2.7097 - output_0_loss: 0.4283 - output_1_loss: 0.4527 - output_2_loss: 0.5541 - output_3_loss: 0.6071 - output_4_loss: 0.6673 - output_0_accuracy: 0.8438 - output_1_accuracy: 0.8203 - output_2_accuracy: 0.7500 - output_3_accuracy: 0.6992 - output_4_accuracy: 0.6006
# trained chunk: 63
# 32/32 [==============================] - 15s 479ms/step - loss: 2.6314 - output_0_loss: 0.4051 - output_1_loss: 0.4221 - output_2_loss: 0.5421 - output_3_loss: 0.5949 - output_4_loss: 0.6672 - output_0_accuracy: 0.8574 - output_1_accuracy: 0.8418 - output_2_accuracy: 0.7559 - output_3_accuracy: 0.7090 - output_4_accuracy: 0.5820
# trained chunk: 64
# 32/32 [==============================] - 15s 469ms/step - loss: 2.7132 - output_0_loss: 0.4186 - output_1_loss: 0.4338 - output_2_loss: 0.5707 - output_3_loss: 0.6170 - output_4_loss: 0.6732 - output_0_accuracy: 0.8545 - output_1_accuracy: 0.8369 - output_2_accuracy: 0.7432 - output_3_accuracy: 0.6895 - output_4_accuracy: 0.5693
# trained chunk: 65
# 32/32 [==============================] - 15s 470ms/step - loss: 2.7016 - output_0_loss: 0.4219 - output_1_loss: 0.4552 - output_2_loss: 0.5718 - output_3_loss: 0.5801 - output_4_loss: 0.6726 - output_0_accuracy: 0.8457 - output_1_accuracy: 0.8252 - output_2_accuracy: 0.7354 - output_3_accuracy: 0.7275 - output_4_accuracy: 0.5918
# trained chunk: 66
# 32/32 [==============================] - 15s 468ms/step - loss: 2.7060 - output_0_loss: 0.4140 - output_1_loss: 0.4580 - output_2_loss: 0.5469 - output_3_loss: 0.6060 - output_4_loss: 0.6812 - output_0_accuracy: 0.8525 - output_1_accuracy: 0.8223 - output_2_accuracy: 0.7646 - output_3_accuracy: 0.7129 - output_4_accuracy: 0.5449
# trained chunk: 67
# 32/32 [==============================] - 15s 466ms/step - loss: 2.7014 - output_0_loss: 0.4284 - output_1_loss: 0.4506 - output_2_loss: 0.5371 - output_3_loss: 0.6098 - output_4_loss: 0.6755 - output_0_accuracy: 0.8467 - output_1_accuracy: 0.8252 - output_2_accuracy: 0.7627 - output_3_accuracy: 0.6982 - output_4_accuracy: 0.5830
# trained chunk: 68
# 32/32 [==============================] - 15s 470ms/step - loss: 2.6662 - output_0_loss: 0.3896 - output_1_loss: 0.4531 - output_2_loss: 0.5618 - output_3_loss: 0.5880 - output_4_loss: 0.6738 - output_0_accuracy: 0.8662 - output_1_accuracy: 0.8203 - output_2_accuracy: 0.7500 - output_3_accuracy: 0.7256 - output_4_accuracy: 0.5596
# trained chunk: 69
# 32/32 [==============================] - 15s 469ms/step - loss: 2.7378 - output_0_loss: 0.3938 - output_1_loss: 0.4987 - output_2_loss: 0.5788 - output_3_loss: 0.5930 - output_4_loss: 0.6734 - output_0_accuracy: 0.8643 - output_1_accuracy: 0.7969 - output_2_accuracy: 0.7314 - output_3_accuracy: 0.7227 - output_4_accuracy: 0.5742
# trained chunk: 70
# 32/32 [==============================] - 15s 465ms/step - loss: 2.6155 - output_0_loss: 0.3550 - output_1_loss: 0.4364 - output_2_loss: 0.5633 - output_3_loss: 0.5885 - output_4_loss: 0.6724 - output_0_accuracy: 0.8838 - output_1_accuracy: 0.8369 - output_2_accuracy: 0.7402 - output_3_accuracy: 0.7148 - output_4_accuracy: 0.5771
# trained chunk: 71
# 32/32 [==============================] - 15s 473ms/step - loss: 2.7131 - output_0_loss: 0.4155 - output_1_loss: 0.4574 - output_2_loss: 0.5694 - output_3_loss: 0.5951 - output_4_loss: 0.6757 - output_0_accuracy: 0.8535 - output_1_accuracy: 0.8242 - output_2_accuracy: 0.7432 - output_3_accuracy: 0.7090 - output_4_accuracy: 0.5791
# trained chunk: 72
# 32/32 [==============================] - 15s 475ms/step - loss: 2.6291 - output_0_loss: 0.3875 - output_1_loss: 0.4317 - output_2_loss: 0.5469 - output_3_loss: 0.5923 - output_4_loss: 0.6707 - output_0_accuracy: 0.8691 - output_1_accuracy: 0.8320 - output_2_accuracy: 0.7578 - output_3_accuracy: 0.7188 - output_4_accuracy: 0.5938
# trained chunk: 73
# 32/32 [==============================] - 15s 469ms/step - loss: 2.6822 - output_0_loss: 0.3886 - output_1_loss: 0.4479 - output_2_loss: 0.5719 - output_3_loss: 0.5960 - output_4_loss: 0.6777 - output_0_accuracy: 0.8691 - output_1_accuracy: 0.8252 - output_2_accuracy: 0.7373 - output_3_accuracy: 0.7129 - output_4_accuracy: 0.5674
# trained chunk: 74
# 32/32 [==============================] - 15s 468ms/step - loss: 2.5888 - output_0_loss: 0.3578 - output_1_loss: 0.4228 - output_2_loss: 0.5545 - output_3_loss: 0.5801 - output_4_loss: 0.6735 - output_0_accuracy: 0.8818 - output_1_accuracy: 0.8379 - output_2_accuracy: 0.7480 - output_3_accuracy: 0.7285 - output_4_accuracy: 0.5537
# trained chunk: 75
# 32/32 [==============================] - 15s 472ms/step - loss: 2.6364 - output_0_loss: 0.3936 - output_1_loss: 0.4282 - output_2_loss: 0.5610 - output_3_loss: 0.5941 - output_4_loss: 0.6595 - output_0_accuracy: 0.8691 - output_1_accuracy: 0.8408 - output_2_accuracy: 0.7500 - output_3_accuracy: 0.7139 - output_4_accuracy: 0.5801
# trained chunk: 76
# 32/32 [==============================] - 15s 472ms/step - loss: 2.6820 - output_0_loss: 0.4005 - output_1_loss: 0.4710 - output_2_loss: 0.5531 - output_3_loss: 0.5859 - output_4_loss: 0.6716 - output_0_accuracy: 0.8613 - output_1_accuracy: 0.8164 - output_2_accuracy: 0.7539 - output_3_accuracy: 0.7305 - output_4_accuracy: 0.5537
# trained chunk: 77
# 18/18 [==============================] - 10s 482ms/step - loss: 2.4155 - output_0_loss: 0.5259 - output_1_loss: 0.3426 - output_2_loss: 0.4439 - output_3_loss: 0.4867 - output_4_loss: 0.6163 - output_0_accuracy: 0.7880 - output_1_accuracy: 0.8922 - output_2_accuracy: 0.8339 - output_3_accuracy: 0.8198 - output_4_accuracy: 0.7279
# trained chunk: 78
# 339/339 [==============================] - 74s 216ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Label 0: Precision=[0.85338381 0.        ], Recall=[1. 0.], F1-score=[0.9208927 0.       ]
# Label 1: Precision=[0.8315916  0.77777778], Recall=[0.99955536 0.00762943], F1-score=[0.90787016 0.01511063]
# Label 2: Precision=[0.75484121 0.64015905], Recall=[0.97730977 0.11282411], F1-score=[0.85178913 0.19183795]
# Label 3: Precision=[0.72007475 0.66716867], Recall=[0.97069743 0.1346914 ], F1-score=[0.82681123 0.22413357]
# Label 4: Precision=[0.57542863 0.78644764], Recall=[0.96462585 0.15471622], F1-score=[0.72084895 0.2585654 ]
