# %%
# !apt-get install -y -qq git
# !git clone https://github.com/ConsenSys/python-solidity-parser.git
# %ls
# %cd python-solidity-parser
# %ls
# !pip install .
from solidity_parser import parser

import sys
import pprint

def parse_solidity_code(source_code):
    try:
        ast = parser.parse(source_code)
        return ast
    except Exception as e:
        print(f"Error parsing Solidity code: {e}",)
        return None

import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

train_df = pd.read_csv('/content/drive/MyDrive/Practicum/SascDatasets/validation_data_source_codes.csv')

# Set of Solidity keywords
solidity_keywords = [
    # Variable Types
    'address', 'bool', 'int', 'int8', 'int16', 'int32', 'int64', 'int128', 'int256', 'uint', 'uint8', 'uint16', 'uint32', 'uint64', 'uint128', 'uint256',
    'float', 'double', 'fixed', 'ufixed', 'byte', 'bytes', 'bytes1', 'bytes2', 'bytes4', 'bytes8', 'bytes16', 'bytes32', 'string', 'mapping', 'struct', 'enum',

    # Control Structures
    'if', 'else', 'while', 'do', 'for', 'switch', 'case', 'default', 'break', 'continue', 'return',
    'throw', 'require', 'revert', 'modifier',

    # Visibility Specifiers
    'public', 'external', 'internal', 'private',

    # Function Modifiers
    'pure', 'view', 'payable', 'constant', 'anonymous'

    # Special Keywords
    'this', 'super', 'selfdestruct', 'assembly',

    # Events
    'event', 'indexed',

    # Built-in Functions
    'msg', 'msg.sender', 'msg.value', 'sender', 'value', 'now', 'block', 'tx', 'origin', 'gasleft', 'assert', 'require', 'revert',
    'keccak256', 'sha256', 'ecrecover', 'addmod', 'mulmod', 'create', 'call', 'delegatecall', 'callcode', 'send',
    'staticcall', 'selfdestruct', 'balance', 'div', 'mod', 'exp', 'sqrt', 'gas', 'this', 'abs', 'min', 'max',
    'balance', 'transfer', 'block', 'number', 'blockHash', 'timestamp',

    # Other
    'constructor', 'fallback', 'receive', 'pragma', 'after', 'alias', 'apply', 'auto', 'case', 'copyof', 'default', 'defined', 'final', 'implements', 'in', 'inline', 'let',
    'macro', 'match', 'mutable', 'null', 'of', 'partial', 'promise', 'reference', 'relocatable', 'sealed', 'sizeof', 'static', 'supports', 'switch', 'typedef', 'typeof', 'var'
]

def get_function_nodes(ast):
    function_nodes = []

    def traverse(node):
        if isinstance(node, dict):
            if 'type' in node and node['type'] == 'FunctionDefinition':
                function_nodes.append(node)
            elif 'type' in node and node['type'] == 'ModifierDefinition':
                function_nodes.append(node)
            for key, value in node.items():
                if isinstance(value, list):
                    for item in value:
                        traverse(item)
                elif isinstance(value, dict):
                    traverse(value)

    traverse(ast)
    return function_nodes

def serialize_function_node(node, keywords):
    serialized_node = []
    has_string_literal_type = False
    has_hex_literal_type = False
    has_hex_number_type = False
    has_decimal_number_type = False

    for key, value in node.items():
        if key == 'name' and value not in keywords:
            value = 'XX'
        elif key == 'namePath' and value not in keywords:
            value = 'XX'
        elif key == 'memberName' and value not in keywords:
            value = 'XX'
        # elif key == 'functionName' and value not in keywords:
        #     value = 'assembly_func'
        elif key == 'decl':
            value = 'parser_error'
        elif key == 'number':
            value = 'num_literal'
        elif key == 'type' and value == 'stringLiteral':
            has_string_literal_type = True
        elif key == 'type' and value == 'hexLiteral':
            has_hex_literal_type = True
        elif key == 'type' and value == 'HexNumber':
            has_hex_number_type = True
        elif key == 'type' and value == 'DecimalNumber':
            has_decimal_number_type = True
        elif key == 'value' and has_string_literal_type:
            value = 'string_literal'
            has_string_literal_type = False
        elif key == 'value' and has_hex_literal_type:
            value = 'hex_literal'
            has_hex_literal_type = False
        elif key == 'value' and has_hex_number_type:
            value = 'hex_value'
            has_hex_number_type = False
        elif key == 'value' and has_decimal_number_type:
            value = 'dec_value'
            has_decimal_number_type = False

        if isinstance(value, list):
            if not value:
                serialized_value = 'empty_list'
            else:
                serialized_value = ' '.join(serialize_function_node(item, keywords) for item in value if isinstance(item, dict))
        elif isinstance(value, dict):
            serialized_value = serialize_function_node(value, keywords)
        else:
            serialized_value = str(value)
        serialized_node.append(f'{key} {serialized_value}')
    return ' '.join(serialized_node)

def serialize_ast(ast, solidity_keywords):

    function_nodes = get_function_nodes(ast)
    serialized_ast = [serialize_function_node(node, solidity_keywords) for node in function_nodes]
    return ' '.join(serialized_ast)


def preprocessDataframe(df, startIndex, rowCount, output_path):
    processed_sequences = []
    for i in range(startIndex, startIndex+rowCount):
        # Step 1: Parse the source code
        ast = parse_solidity_code(df.iloc[i]['source_code'])

        # Step 2: Serialize the AST
        try:
            serialized_ast = serialize_ast(ast, solidity_keywords)
        except Exception as e:
            print("Error serializing AST: ", e)
            serialized_ast = "unserializable"

        processed_sequences.append(serialized_ast)

        # Print progress after every 1000 rows
        if (i - startIndex + 1) % 500 == 0:
            print(f"{i - startIndex + 1} rows processed")

    # Create a new DataFrame with the processed sequences and 'slither' column
    processed_df = pd.DataFrame({'processed_sequence': processed_sequences,
                                 'labels': df['slither'].iloc[startIndex:startIndex + rowCount]})

    # Save the new DataFrame to a CSV file
    processed_df.to_csv(output_path, index=False)

startIndex = 0
rowCount = 10606
training_output_path = f'/content/drive/MyDrive/Practicum/ASTDataChunked/validation_ast_sequences.csv'
preprocessDataframe(train_df, startIndex, rowCount, training_output_path)
# Out:
# Cloning into 'python-solidity-parser'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 198 (delta 55), reused 49 (delta 49), pack-reused 138
# Receiving objects: 100% (198/198), 270.51 KiB | 3.14 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# drive/  python-solidity-parser/  sample_data/
# /content/python-solidity-parser
# README.md         samples/  setup.py          solidity_parser/
# requirements.txt  scripts/  solidity-antlr4/
# Processing /content/python-solidity-parser
#   Preparing metadata (setup.py) ... done
# Collecting antlr4-python3-runtime==4.9.3 (from solidity-parser==0.1.1)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: solidity-parser, antlr4-python3-runtime
#   Building wheel for solidity-parser (setup.py) ... done
#   Created wheel for solidity-parser: filename=solidity_parser-0.1.1-py3-none-any.whl size=67337 sha256=d5be30cb4df209ce7c8deb9bf6d58634ac41ad6b56fd2501456fc5cc8f4181a2
#   Stored in directory: /root/.cache/pip/wheels/6c/04/a4/9bab35dd96f0494763c278dbe3f664d449e5f59875cab4f80c
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144552 sha256=c1c833e1b8c782cb19ca84b06231324bde702ba224b1b9aa8b5dd971e8eebeab
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built solidity-parser antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, solidity-parser
# Successfully installed antlr4-python3-runtime-4.9.3 solidity-parser-0.1.1
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# line 1249:1 missing 'constant' at 'SExactGauge'
# line 1249:13 mismatched input 'is' expecting '='
# line 1249:30 mismatched input ',' expecting 'constant'
# line 1249:45 mismatched input '{' expecting 'constant'
# line 1252:19 mismatched input 'for' expecting 'constant'
# line 1252:27 mismatched input ';' expecting 'constant'
# line 1255:25 mismatched input 'for' expecting 'constant'
# line 1255:36 mismatched input ';' expecting 'constant'
# line 1261:12 extraneous input 'internal' expecting 'constant'
# line 1264:12 extraneous input 'internal' expecting 'constant'
# line 1267:12 extraneous input 'internal' expecting 'constant'
# line 1270:12 extraneous input 'internal' expecting 'constant'
# line 1273:12 extraneous input 'internal' expecting 'constant'
# line 1279:12 mismatched input 'override' expecting 'constant'
# line 1279:34 mismatched input ';' expecting 'constant'
# line 1282:12 mismatched input 'override' expecting 'constant'
# line 1282:37 mismatched input ';' expecting 'constant'
# line 1285:12 mismatched input 'override' expecting 'constant'
# line 1285:36 mismatched input ';' expecting 'constant'
# line 1288:12 mismatched input 'override' expecting 'constant'
# line 1288:38 mismatched input ';' expecting 'constant'
# line 1291:12 mismatched input 'override' expecting 'constant'
# line 1291:41 mismatched input ';' expecting 'constant'
# line 1294:29 mismatched input 'override' expecting 'constant'
# line 1294:54 mismatched input ';' expecting 'constant'
# line 1297:9 mismatched input 'override' expecting 'constant'
# line 1297:36 mismatched input ';' expecting 'constant'
# line 1300:9 mismatched input 'override' expecting 'constant'
# line 1300:42 mismatched input ';' expecting 'constant'
# line 1309:49 mismatched input 'override' expecting 'constant'
# line 1309:84 mismatched input ';' expecting 'constant'
# line 1315:29 mismatched input 'override' expecting 'constant'
# line 1315:61 mismatched input ';' expecting 'constant'
# line 1318:9 mismatched input 'override' expecting 'constant'
# line 1318:39 mismatched input ';' expecting 'constant'
# line 1330:11 mismatched input 'override' expecting 'constant'
# line 1330:33 mismatched input ';' expecting 'constant'
# line 1333:44 mismatched input 'override' expecting 'constant'
# line 1333:76 mismatched input ';' expecting 'constant'
# line 1342:44 mismatched input 'override' expecting 'constant'
# line 1342:80 mismatched input ';' expecting 'constant'
# line 1351:29 mismatched input 'override' expecting 'constant'
# line 1351:68 mismatched input ';' expecting 'constant'
# line 1354:29 mismatched input 'override' expecting 'constant'
# line 1354:68 mismatched input ';' expecting 'constant'
# line 1366:29 mismatched input 'override' expecting 'constant'
# line 1366:63 mismatched input ';' expecting 'constant'
# line 1372:9 mismatched input 'override' expecting 'constant'
# line 1372:39 mismatched input ';' expecting 'constant'
# line 1381:12 mismatched input 'override' expecting 'constant'
# line 1381:43 mismatched input ';' expecting 'constant'
# line 1384:12 mismatched input 'override' expecting 'constant'
# line 1384:42 mismatched input ';' expecting 'constant'
# line 1390:29 mismatched input 'public' expecting 'constant'
# line 1390:52 mismatched input ';' expecting 'constant'
# line 1393:49 mismatched input 'public' expecting 'constant'
# line 1393:76 mismatched input ';' expecting 'constant'
# line 1396:49 mismatched input 'public' expecting 'constant'
# line 1396:68 mismatched input ';' expecting 'constant'
# line 1399:49 mismatched input 'public' expecting 'constant'
# line 1399:76 mismatched input ';' expecting 'constant'
# line 1405:6 mismatched input 'public' expecting 'constant'
# line 1405:17 mismatched input ';' expecting 'constant'
# line 1408:6 mismatched input 'public' expecting 'constant'
# line 1408:16 mismatched input ';' expecting 'constant'
# line 1411:26 mismatched input 'public' expecting 'constant'
# line 1411:47 mismatched input ';' expecting 'constant'
# line 1414:6 mismatched input 'public' expecting 'constant'
# line 1414:25 mismatched input ';' expecting 'constant'
# line 1417:6 mismatched input 'public' expecting 'constant'
# line 1417:22 mismatched input ';' expecting 'constant'
# line 1420:6 mismatched input 'public' expecting 'constant'
# line 1420:21 mismatched input ';' expecting 'constant'
# line 1933:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1944:0 missing 'constant' at 'uge'
# line 1944:4 mismatched input 'is' expecting '='
# line 1944:19 mismatched input '{' expecting 'constant'
# line 1947:11 mismatched input 'public' expecting 'constant'
# line 1947:25 mismatched input ';' expecting 'constant'
# line 2253:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2264:1 mismatched input 'is' expecting 'constant'
# line 2264:10 mismatched input ',' expecting 'constant'
# line 2264:25 mismatched input '{' expecting 'constant'
# line 2267:19 mismatched input 'for' expecting 'constant'
# line 2267:27 mismatched input ';' expecting 'constant'
# line 2270:18 mismatched input 'for' expecting 'constant'
# line 2270:37 mismatched input ';' expecting 'constant'
# line 2273:25 mismatched input 'for' expecting 'constant'
# line 2273:36 mismatched input ';' expecting 'constant'
# line 2279:9 extraneous input 'internal' expecting 'constant'
# line 2282:9 extraneous input 'internal' expecting 'constant'
# line 2285:9 extraneous input 'internal' expecting 'constant'
# line 2291:12 mismatched input 'override' expecting 'constant'
# line 2291:33 mismatched input ';' expecting 'constant'
# line 2294:12 mismatched input 'override' expecting 'constant'
# line 2294:38 mismatched input ';' expecting 'constant'
# line 2297:49 mismatched input 'override' expecting 'constant'
# line 2297:71 mismatched input ';' expecting 'constant'
# line 2300:49 mismatched input 'override' expecting 'constant'
# line 2300:84 mismatched input ';' expecting 'constant'
# line 2303:29 mismatched input 'public' expecting 'constant'
# line 2303:42 mismatched input ';' expecting 'constant'
# line 2450:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2940:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1140:1 missing 'constant' at 'SExactGauge'
# line 1140:13 mismatched input 'is' expecting '='
# line 1140:30 mismatched input ',' expecting 'constant'
# line 1140:45 mismatched input '{' expecting 'constant'
# line 1143:19 mismatched input 'for' expecting 'constant'
# line 1143:27 mismatched input ';' expecting 'constant'
# line 1146:25 mismatched input 'for' expecting 'constant'
# line 1146:36 mismatched input ';' expecting 'constant'
# line 1152:12 extraneous input 'internal' expecting 'constant'
# line 1155:12 extraneous input 'internal' expecting 'constant'
# line 1158:12 extraneous input 'internal' expecting 'constant'
# line 1161:12 extraneous input 'internal' expecting 'constant'
# line 1164:12 extraneous input 'internal' expecting 'constant'
# line 1170:12 mismatched input 'override' expecting 'constant'
# line 1170:34 mismatched input ';' expecting 'constant'
# line 1173:12 mismatched input 'override' expecting 'constant'
# line 1173:37 mismatched input ';' expecting 'constant'
# line 1176:12 mismatched input 'override' expecting 'constant'
# line 1176:36 mismatched input ';' expecting 'constant'
# line 1179:12 mismatched input 'override' expecting 'constant'
# line 1179:38 mismatched input ';' expecting 'constant'
# line 1182:12 mismatched input 'override' expecting 'constant'
# line 1182:41 mismatched input ';' expecting 'constant'
# line 1185:29 mismatched input 'override' expecting 'constant'
# line 1185:54 mismatched input ';' expecting 'constant'
# line 1188:9 mismatched input 'override' expecting 'constant'
# line 1188:36 mismatched input ';' expecting 'constant'
# line 1191:9 mismatched input 'override' expecting 'constant'
# line 1191:42 mismatched input ';' expecting 'constant'
# line 1200:49 mismatched input 'override' expecting 'constant'
# line 1200:84 mismatched input ';' expecting 'constant'
# line 1206:29 mismatched input 'override' expecting 'constant'
# line 1206:61 mismatched input ';' expecting 'constant'
# line 1209:9 mismatched input 'override' expecting 'constant'
# line 1209:39 mismatched input ';' expecting 'constant'
# line 1221:11 mismatched input 'override' expecting 'constant'
# line 1221:33 mismatched input ';' expecting 'constant'
# line 1224:44 mismatched input 'override' expecting 'constant'
# line 1224:76 mismatched input ';' expecting 'constant'
# line 1233:44 mismatched input 'override' expecting 'constant'
# line 1233:80 mismatched input ';' expecting 'constant'
# line 1242:29 mismatched input 'override' expecting 'constant'
# line 1242:68 mismatched input ';' expecting 'constant'
# line 1245:29 mismatched input 'override' expecting 'constant'
# line 1245:68 mismatched input ';' expecting 'constant'
# line 1257:29 mismatched input 'override' expecting 'constant'
# line 1257:63 mismatched input ';' expecting 'constant'
# line 1263:9 mismatched input 'override' expecting 'constant'
# line 1263:39 mismatched input ';' expecting 'constant'
# line 1272:12 mismatched input 'override' expecting 'constant'
# line 1272:43 mismatched input ';' expecting 'constant'
# line 1275:12 mismatched input 'override' expecting 'constant'
# line 1275:42 mismatched input ';' expecting 'constant'
# line 1281:29 mismatched input 'public' expecting 'constant'
# line 1281:52 mismatched input ';' expecting 'constant'
# line 1284:49 mismatched input 'public' expecting 'constant'
# line 1284:76 mismatched input ';' expecting 'constant'
# line 1287:49 mismatched input 'public' expecting 'constant'
# line 1287:68 mismatched input ';' expecting 'constant'
# line 1290:49 mismatched input 'public' expecting 'constant'
# line 1290:76 mismatched input ';' expecting 'constant'
# line 1296:6 mismatched input 'public' expecting 'constant'
# line 1296:17 mismatched input ';' expecting 'constant'
# line 1299:6 mismatched input 'public' expecting 'constant'
# line 1299:16 mismatched input ';' expecting 'constant'
# line 1302:26 mismatched input 'public' expecting 'constant'
# line 1302:47 mismatched input ';' expecting 'constant'
# line 1305:6 mismatched input 'public' expecting 'constant'
# line 1305:25 mismatched input ';' expecting 'constant'
# line 1308:6 mismatched input 'public' expecting 'constant'
# line 1308:22 mismatched input ';' expecting 'constant'
# line 1311:6 mismatched input 'public' expecting 'constant'
# line 1311:21 mismatched input ';' expecting 'constant'
# line 1824:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1835:0 missing 'constant' at 'uge'
# line 1835:4 mismatched input 'is' expecting '='
# line 1835:19 mismatched input '{' expecting 'constant'
# line 1838:11 mismatched input 'public' expecting 'constant'
# line 1838:25 mismatched input ';' expecting 'constant'
# line 2144:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2155:1 mismatched input 'is' expecting 'constant'
# line 2155:10 mismatched input ',' expecting 'constant'
# line 2155:25 mismatched input '{' expecting 'constant'
# line 2158:19 mismatched input 'for' expecting 'constant'
# line 2158:27 mismatched input ';' expecting 'constant'
# line 2161:18 mismatched input 'for' expecting 'constant'
# line 2161:37 mismatched input ';' expecting 'constant'
# line 2164:25 mismatched input 'for' expecting 'constant'
# line 2164:36 mismatched input ';' expecting 'constant'
# line 2170:9 extraneous input 'internal' expecting 'constant'
# line 2173:9 extraneous input 'internal' expecting 'constant'
# line 2176:9 extraneous input 'internal' expecting 'constant'
# line 2182:12 mismatched input 'override' expecting 'constant'
# line 2182:33 mismatched input ';' expecting 'constant'
# line 2185:12 mismatched input 'override' expecting 'constant'
# line 2185:38 mismatched input ';' expecting 'constant'
# line 2188:49 mismatched input 'override' expecting 'constant'
# line 2188:71 mismatched input ';' expecting 'constant'
# line 2191:49 mismatched input 'override' expecting 'constant'
# line 2191:84 mismatched input ';' expecting 'constant'
# line 2194:29 mismatched input 'public' expecting 'constant'
# line 2194:42 mismatched input ';' expecting 'constant'
# line 2341:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2831:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1140:1 missing 'constant' at 'SExactGauge'
# line 1140:13 mismatched input 'is' expecting '='
# line 1140:30 mismatched input ',' expecting 'constant'
# line 1140:45 mismatched input '{' expecting 'constant'
# line 1143:19 mismatched input 'for' expecting 'constant'
# line 1143:27 mismatched input ';' expecting 'constant'
# line 1146:25 mismatched input 'for' expecting 'constant'
# line 1146:36 mismatched input ';' expecting 'constant'
# line 1152:12 extraneous input 'internal' expecting 'constant'
# line 1155:12 extraneous input 'internal' expecting 'constant'
# line 1158:12 extraneous input 'internal' expecting 'constant'
# line 1161:12 extraneous input 'internal' expecting 'constant'
# line 1167:12 mismatched input 'override' expecting 'constant'
# line 1167:34 mismatched input ';' expecting 'constant'
# line 1170:12 mismatched input 'override' expecting 'constant'
# line 1170:37 mismatched input ';' expecting 'constant'
# line 1173:12 mismatched input 'override' expecting 'constant'
# line 1173:36 mismatched input ';' expecting 'constant'
# line 1176:12 mismatched input 'override' expecting 'constant'
# line 1176:38 mismatched input ';' expecting 'constant'
# line 1179:12 mismatched input 'override' expecting 'constant'
# line 1179:41 mismatched input ';' expecting 'constant'
# line 1182:29 mismatched input 'override' expecting 'constant'
# line 1182:54 mismatched input ';' expecting 'constant'
# line 1185:9 mismatched input 'override' expecting 'constant'
# line 1185:36 mismatched input ';' expecting 'constant'
# line 1188:9 mismatched input 'override' expecting 'constant'
# line 1188:42 mismatched input ';' expecting 'constant'
# line 1197:49 mismatched input 'override' expecting 'constant'
# line 1197:84 mismatched input ';' expecting 'constant'
# line 1203:29 mismatched input 'override' expecting 'constant'
# line 1203:61 mismatched input ';' expecting 'constant'
# line 1206:9 mismatched input 'override' expecting 'constant'
# line 1206:39 mismatched input ';' expecting 'constant'
# line 1218:11 mismatched input 'override' expecting 'constant'
# line 1218:33 mismatched input ';' expecting 'constant'
# line 1221:44 mismatched input 'override' expecting 'constant'
# line 1221:76 mismatched input ';' expecting 'constant'
# line 1230:44 mismatched input 'override' expecting 'constant'
# line 1230:80 mismatched input ';' expecting 'constant'
# line 1239:29 mismatched input 'override' expecting 'constant'
# line 1239:68 mismatched input ';' expecting 'constant'
# line 1242:29 mismatched input 'override' expecting 'constant'
# line 1242:68 mismatched input ';' expecting 'constant'
# line 1254:29 mismatched input 'override' expecting 'constant'
# line 1254:63 mismatched input ';' expecting 'constant'
# line 1260:9 mismatched input 'override' expecting 'constant'
# line 1260:39 mismatched input ';' expecting 'constant'
# line 1269:12 mismatched input 'override' expecting 'constant'
# line 1269:43 mismatched input ';' expecting 'constant'
# line 1272:12 mismatched input 'override' expecting 'constant'
# line 1272:42 mismatched input ';' expecting 'constant'
# line 1278:29 mismatched input 'public' expecting 'constant'
# line 1278:52 mismatched input ';' expecting 'constant'
# line 1281:49 mismatched input 'public' expecting 'constant'
# line 1281:76 mismatched input ';' expecting 'constant'
# line 1284:49 mismatched input 'public' expecting 'constant'
# line 1284:68 mismatched input ';' expecting 'constant'
# line 1287:49 mismatched input 'public' expecting 'constant'
# line 1287:76 mismatched input ';' expecting 'constant'
# line 1293:6 mismatched input 'public' expecting 'constant'
# line 1293:17 mismatched input ';' expecting 'constant'
# line 1296:6 mismatched input 'public' expecting 'constant'
# line 1296:16 mismatched input ';' expecting 'constant'
# line 1299:26 mismatched input 'public' expecting 'constant'
# line 1299:47 mismatched input ';' expecting 'constant'
# line 1302:6 mismatched input 'public' expecting 'constant'
# line 1302:25 mismatched input ';' expecting 'constant'
# line 1305:6 mismatched input 'public' expecting 'constant'
# line 1305:22 mismatched input ';' expecting 'constant'
# line 1308:6 mismatched input 'public' expecting 'constant'
# line 1308:21 mismatched input ';' expecting 'constant'
# line 1800:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1811:0 missing 'constant' at 'uge'
# line 1811:4 mismatched input 'is' expecting '='
# line 1811:19 mismatched input '{' expecting 'constant'
# line 1814:11 mismatched input 'public' expecting 'constant'
# line 1814:25 mismatched input ';' expecting 'constant'
# line 2111:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2122:1 mismatched input 'is' expecting 'constant'
# line 2122:10 mismatched input ',' expecting 'constant'
# line 2122:25 mismatched input '{' expecting 'constant'
# line 2125:19 mismatched input 'for' expecting 'constant'
# line 2125:27 mismatched input ';' expecting 'constant'
# line 2128:18 mismatched input 'for' expecting 'constant'
# line 2128:37 mismatched input ';' expecting 'constant'
# line 2131:25 mismatched input 'for' expecting 'constant'
# line 2131:36 mismatched input ';' expecting 'constant'
# line 2137:9 extraneous input 'internal' expecting 'constant'
# line 2140:9 extraneous input 'internal' expecting 'constant'
# line 2143:9 extraneous input 'internal' expecting 'constant'
# line 2149:12 mismatched input 'override' expecting 'constant'
# line 2149:33 mismatched input ';' expecting 'constant'
# line 2152:12 mismatched input 'override' expecting 'constant'
# line 2152:38 mismatched input ';' expecting 'constant'
# line 2155:49 mismatched input 'override' expecting 'constant'
# line 2155:71 mismatched input ';' expecting 'constant'
# line 2158:49 mismatched input 'override' expecting 'constant'
# line 2158:84 mismatched input ';' expecting 'constant'
# line 2161:29 mismatched input 'public' expecting 'constant'
# line 2161:42 mismatched input ';' expecting 'constant'
# line 2293:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2783:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 530:5 token recognition error at: '�'
# line 530:6 token recognition error at: 'ɹ'
# line 530:7 token recognition error at: '�'
# line 530:8 token recognition error at: 'ִ'
# line 530:9 token recognition error at: '�'
# line 530:10 token recognition error at: '�'
# line 530:11 token recognition error at: 'ʱ'
# line 530:12 token recognition error at: '�'
# line 530:13 token recognition error at: '�'
# line 530:14 token recognition error at: '�'
# line 530:15 token recognition error at: '봥'
# line 530:16 token recognition error at: '�'
# line 530:17 token recognition error at: '�'
# line 530:18 token recognition error at: '�'
# line 530:19 token recognition error at: '�'
# line 530:20 token recognition error at: '�'
# line 530:21 token recognition error at: '¼'
# line 530:22 token recognition error at: '�'
# line 530:4 mismatched input ')' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# Error parsing Solidity code: 'NoneType' object has no attribute 'getText'
# line 1140:1 missing 'constant' at 'SExactGauge'
# line 1140:13 mismatched input 'is' expecting '='
# line 1140:30 mismatched input ',' expecting 'constant'
# line 1140:45 mismatched input '{' expecting 'constant'
# line 1143:19 mismatched input 'for' expecting 'constant'
# line 1143:27 mismatched input ';' expecting 'constant'
# line 1146:25 mismatched input 'for' expecting 'constant'
# line 1146:36 mismatched input ';' expecting 'constant'
# line 1152:12 extraneous input 'internal' expecting 'constant'
# line 1155:12 extraneous input 'internal' expecting 'constant'
# line 1158:12 extraneous input 'internal' expecting 'constant'
# line 1161:12 extraneous input 'internal' expecting 'constant'
# line 1167:12 mismatched input 'override' expecting 'constant'
# line 1167:34 mismatched input ';' expecting 'constant'
# line 1170:12 mismatched input 'override' expecting 'constant'
# line 1170:37 mismatched input ';' expecting 'constant'
# line 1173:12 mismatched input 'override' expecting 'constant'
# line 1173:36 mismatched input ';' expecting 'constant'
# line 1176:12 mismatched input 'override' expecting 'constant'
# line 1176:38 mismatched input ';' expecting 'constant'
# line 1179:12 mismatched input 'override' expecting 'constant'
# line 1179:41 mismatched input ';' expecting 'constant'
# line 1182:29 mismatched input 'override' expecting 'constant'
# line 1182:54 mismatched input ';' expecting 'constant'
# line 1185:9 mismatched input 'override' expecting 'constant'
# line 1185:36 mismatched input ';' expecting 'constant'
# line 1188:9 mismatched input 'override' expecting 'constant'
# line 1188:42 mismatched input ';' expecting 'constant'
# line 1197:49 mismatched input 'override' expecting 'constant'
# line 1197:84 mismatched input ';' expecting 'constant'
# line 1203:29 mismatched input 'override' expecting 'constant'
# line 1203:61 mismatched input ';' expecting 'constant'
# line 1206:9 mismatched input 'override' expecting 'constant'
# line 1206:39 mismatched input ';' expecting 'constant'
# line 1218:11 mismatched input 'override' expecting 'constant'
# line 1218:33 mismatched input ';' expecting 'constant'
# line 1221:44 mismatched input 'override' expecting 'constant'
# line 1221:76 mismatched input ';' expecting 'constant'
# line 1230:44 mismatched input 'override' expecting 'constant'
# line 1230:80 mismatched input ';' expecting 'constant'
# line 1239:29 mismatched input 'override' expecting 'constant'
# line 1239:68 mismatched input ';' expecting 'constant'
# line 1242:29 mismatched input 'override' expecting 'constant'
# line 1242:68 mismatched input ';' expecting 'constant'
# line 1254:29 mismatched input 'override' expecting 'constant'
# line 1254:63 mismatched input ';' expecting 'constant'
# line 1260:9 mismatched input 'override' expecting 'constant'
# line 1260:39 mismatched input ';' expecting 'constant'
# line 1269:12 mismatched input 'override' expecting 'constant'
# line 1269:43 mismatched input ';' expecting 'constant'
# line 1272:12 mismatched input 'override' expecting 'constant'
# line 1272:42 mismatched input ';' expecting 'constant'
# line 1278:9 mismatched input 'override' expecting 'constant'
# line 1278:40 mismatched input ';' expecting 'constant'
# line 1281:29 mismatched input 'override' expecting 'constant'
# line 1281:64 mismatched input ';' expecting 'constant'
# line 1284:29 mismatched input 'override' expecting 'constant'
# line 1284:56 mismatched input ';' expecting 'constant'
# line 1287:29 mismatched input 'override' expecting 'constant'
# line 1287:64 mismatched input ';' expecting 'constant'
# line 1293:6 mismatched input 'public' expecting 'constant'
# line 1293:17 mismatched input ';' expecting 'constant'
# line 1296:6 mismatched input 'public' expecting 'constant'
# line 1296:16 mismatched input ';' expecting 'constant'
# line 1299:26 mismatched input 'public' expecting 'constant'
# line 1299:47 mismatched input ';' expecting 'constant'
# line 1302:6 mismatched input 'public' expecting 'constant'
# line 1302:25 mismatched input ';' expecting 'constant'
# line 1305:6 mismatched input 'public' expecting 'constant'
# line 1305:22 mismatched input ';' expecting 'constant'
# line 1308:6 mismatched input 'public' expecting 'constant'
# line 1308:21 mismatched input ';' expecting 'constant'
# line 1752:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1763:0 missing 'constant' at 'uge'
# line 1763:4 mismatched input 'is' expecting '='
# line 1763:19 mismatched input '{' expecting 'constant'
# line 1766:11 mismatched input 'public' expecting 'constant'
# line 1766:25 mismatched input ';' expecting 'constant'
# line 1769:45 mismatched input 'public' expecting 'constant'
# line 1769:66 mismatched input ';' expecting 'constant'
# line 1772:26 mismatched input 'public' expecting 'constant'
# line 1772:45 mismatched input ';' expecting 'constant'
# line 1982:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 1993:1 mismatched input 'is' expecting 'constant'
# line 1993:10 mismatched input ',' expecting 'constant'
# line 1993:25 mismatched input '{' expecting 'constant'
# line 1996:19 mismatched input 'for' expecting 'constant'
# line 1996:27 mismatched input ';' expecting 'constant'
# line 1999:18 mismatched input 'for' expecting 'constant'
# line 1999:37 mismatched input ';' expecting 'constant'
# line 2002:25 mismatched input 'for' expecting 'constant'
# line 2002:36 mismatched input ';' expecting 'constant'
# line 2008:9 extraneous input 'internal' expecting 'constant'
# line 2011:9 extraneous input 'internal' expecting 'constant'
# line 2014:9 extraneous input 'internal' expecting 'constant'
# line 2020:12 mismatched input 'override' expecting 'constant'
# line 2020:33 mismatched input ';' expecting 'constant'
# line 2023:12 mismatched input 'override' expecting 'constant'
# line 2023:38 mismatched input ';' expecting 'constant'
# line 2026:49 mismatched input 'override' expecting 'constant'
# line 2026:71 mismatched input ';' expecting 'constant'
# line 2029:49 mismatched input 'override' expecting 'constant'
# line 2029:84 mismatched input ';' expecting 'constant'
# line 2032:29 mismatched input 'public' expecting 'constant'
# line 2032:42 mismatched input ';' expecting 'constant'
# line 2164:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 2654:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 1000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 1500 rows processed
# line 480:11 no viable alternative at input 'functionfallback'
# line 487:4 extraneous input 'fallback' expecting {'~', 'from', '{', '}', '(', 'error', 'for', 'function', '[', 'address', 'mapping', 'calldata', 'if', 'try', 'while', 'unchecked', 'assembly', 'do', 'return', 'throw', 'emit', 'revert', 'var', 'bool', 'string', 'byte', '++', '--', 'new', '+', '-', 'after', 'delete', '!', 'callback', Int, Uint, Byte, Fixed, Ufixed, BooleanLiteral, DecimalNumber, HexNumber, HexLiteralFragment, 'break', 'continue', 'leave', 'payable', 'type', 'constructor', 'receive', Identifier, StringLiteralFragment}
# line 780:11 no viable alternative at input 'functionfallback'
# Error parsing Solidity code: 'NoneType' object is not subscriptable
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 2000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 2500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# line 488:11 no viable alternative at input 'functionfallback'
# line 496:4 extraneous input 'fallback' expecting {'~', 'from', '{', '}', '(', 'error', 'for', 'function', '[', 'address', 'mapping', 'calldata', 'if', 'try', 'while', 'unchecked', 'assembly', 'do', 'return', 'throw', 'emit', 'revert', 'var', 'bool', 'string', 'byte', '++', '--', 'new', '+', '-', 'after', 'delete', '!', 'callback', Int, Uint, Byte, Fixed, Ufixed, BooleanLiteral, DecimalNumber, HexNumber, HexLiteralFragment, 'break', 'continue', 'leave', 'payable', 'type', 'constructor', 'receive', Identifier, StringLiteralFragment}
# line 782:11 no viable alternative at input 'functionfallback'
# Error parsing Solidity code: 'NoneType' object is not subscriptable
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 3000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 3500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# line 56:30 token recognition error at: '#'
# line 56:29 extraneous input '&' expecting {'~', 'from', '(', 'error', '[', 'address', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', '++', '--', 'new', '+', '-', 'after', 'delete', '!', 'callback', Int, Uint, Byte, Fixed, Ufixed, BooleanLiteral, DecimalNumber, HexNumber, HexLiteralFragment, 'leave', 'payable', 'type', 'constructor', 'receive', Identifier, StringLiteralFragment}
# line 56:44 token recognition error at: '#'
# line 56:43 mismatched input '&' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 57:26 token recognition error at: '#'
# line 57:25 extraneous input '&' expecting {'~', 'from', '(', 'error', '[', 'address', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', '++', '--', 'new', '+', '-', 'after', 'delete', '!', 'callback', Int, Uint, Byte, Fixed, Ufixed, BooleanLiteral, DecimalNumber, HexNumber, HexLiteralFragment, 'leave', 'payable', 'type', 'constructor', 'receive', Identifier, StringLiteralFragment}
# line 57:35 token recognition error at: '#'
# line 57:34 mismatched input '&' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 58:28 token recognition error at: '#'
# line 58:27 extraneous input '&' expecting {'~', 'from', '(', 'error', '[', 'address', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', '++', '--', 'new', '+', '-', 'after', 'delete', '!', 'callback', Int, Uint, Byte, Fixed, Ufixed, BooleanLiteral, DecimalNumber, HexNumber, HexLiteralFragment, 'leave', 'payable', 'type', 'constructor', 'receive', Identifier, StringLiteralFragment}
# line 58:37 token recognition error at: '#'
# line 58:36 mismatched input '&' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# Error parsing Solidity code: 'NoneType' object has no attribute 'getText'
# Error parsing Solidity code: maximum recursion depth exceeded in comparison
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 4000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# line 224:48 mismatched input '.' expecting {';', '{', 'returns'}
# line 224:62 mismatched input '{' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 230:23 extraneous input '(' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 230:39 mismatched input '(' expecting {';', '='}
# line 230:54 mismatched input ')' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 230:64 mismatched input '(' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 231:23 extraneous input '{' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 231:29 mismatched input ':' expecting {';', '='}
# line 231:34 mismatched input '}' expecting {'from', 'error', 'calldata', 'revert', 'callback', 'override', 'constant', 'immutable', 'leave', 'internal', 'payable', 'private', 'public', 'constructor', 'receive', Identifier}
# line 231:35 extraneous input '(' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# line 231:39 mismatched input ')' expecting 'constant'
# line 234:18 mismatched input '(' expecting 'constant'
# line 234:35 mismatched input ',' expecting 'constant'
# line 234:44 mismatched input '(' expecting 'constant'
# line 234:49 mismatched input ')' expecting 'constant'
# line 234:58 mismatched input ')' expecting 'constant'
# line 566:0 extraneous input '}' expecting {<EOF>, 'pragma', 'import', 'from', 'abstract', 'contract', 'interface', 'library', 'error', 'struct', 'function', 'enum', 'address', 'mapping', 'calldata', 'revert', 'var', 'bool', 'string', 'byte', 'callback', Int, Uint, Byte, Fixed, Ufixed, 'leave', 'payable', 'type', 'constructor', 'fallback', 'receive', Identifier}
# Error parsing Solidity code: 'NoneType' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 4500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 5000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 5500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# line 420:11 no viable alternative at input 'functionfallback'
# line 427:4 extraneous input 'fallback' expecting {'~', 'from', '{', '}', '(', 'error', 'for', 'function', '[', 'address', 'mapping', 'calldata', 'if', 'try', 'while', 'unchecked', 'assembly', 'do', 'return', 'throw', 'emit', 'revert', 'var', 'bool', 'string', 'byte', '++', '--', 'new', '+', '-', 'after', 'delete', '!', 'callback', Int, Uint, Byte, Fixed, Ufixed, BooleanLiteral, DecimalNumber, HexNumber, HexLiteralFragment, 'break', 'continue', 'leave', 'payable', 'type', 'constructor', 'receive', Identifier, StringLiteralFragment}
# line 570:11 no viable alternative at input 'functionfallback'
# Error parsing Solidity code: 'NoneType' object is not subscriptable
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# ...
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 7500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 8000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 8500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 9000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 9500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 10000 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'list' object has no attribute 'getText'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# 10500 rows processed
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'
# Error parsing Solidity code: 'NoneType' object has no attribute 'identifier'

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
train_df = pd.read_csv('/content/drive/MyDrive/Practicum/ASTDataChunked/validation_ast_sequences.csv')

print(train_df.shape)
# Out:
# Mounted at /content/drive
# (10606, 2)

# %%
print(train_df.head(2))
# Out:
#                                   processed_sequence        labels
# 0  type FunctionDefinition name constructor param...           [4]
# 1  type ModifierDefinition name XX parameters typ...  [5, 3, 2, 1]

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

path = f'/content/drive/MyDrive/Practicum/ASTDataChunked/validation_ast_sequences.csv'
print(f"reading file as: {path}")
train_df = pd.read_csv(path)
print(f'shape: {train_df.shape}')

# remove nan values
train_df = train_df[train_df['processed_sequence'].apply(lambda x: isinstance(x, str))]
print(f'shape after removing NaN values: {train_df.shape}')

import pickle

# Load the saved tokenizer from the file
tokenizer_filename = '/content/drive/MyDrive/Practicum/Utils/ast_tokenizer_train.pkl'
with open(tokenizer_filename, 'rb') as file:
    tokenizer = pickle.load(file)

vocabulary_size = len(tokenizer.word_index)
print("Vocabulary size:", vocabulary_size)

sequences = tokenizer.texts_to_sequences(train_df['processed_sequence'])

from keras.utils import pad_sequences

MSL = 21500
padded_sequences = pad_sequences(sequences, maxlen=MSL, padding='post', truncating='post')

from sklearn.preprocessing import MultiLabelBinarizer
import ast
import numpy as np

# Pad the sequences to a fixed length
labels = [0, 1, 2, 3, 4, 5]

def convertLabelListToArray(labelList):
    labelArrays = labelList.apply(lambda x: np.array(x.strip('[]').split(',')).astype(int))
    mlb = MultiLabelBinarizer(classes=labels)
    binaryLabels = mlb.fit_transform(labelArrays)
    return binaryLabels

binary_labels = convertLabelListToArray(train_df['labels'])

sequence_pd = pd.DataFrame(padded_sequences)
labels = pd.DataFrame(binary_labels)

print(sequence_pd.shape)
print(labels.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# reading file as: /content/drive/MyDrive/Practicum/ASTDataChunked/validation_ast_sequences.csv
# shape: (10606, 2)
# shape after removing NaN values: (10175, 2)
# Vocabulary size: 1742
# (10175, 21500)
# (10175, 6)

# %%
import h5py

# Create the HDF5 file
hdf5_path = '/content/drive/MyDrive/Practicum/HDF5DataAst/validation.h5'
with h5py.File(hdf5_path, 'w') as hdf5_file:
    # Save sequence_pd to an HDF5 dataset
    hdf5_file.create_dataset('data', data=padded_sequences)

    # Save labels to an HDF5 dataset
    hdf5_file.create_dataset('labels', data=binary_labels)

# %%
hdf5_file_training = h5py.File('/content/drive/MyDrive/Practicum/HDF5DataAst/validation.h5', 'r')
training_data = hdf5_file_training['data']
training_labels = hdf5_file_training['labels']
print(training_data.shape)
print(training_labels.shape)
# Out:
# (10175, 21500)
# (10175, 6)
